# %%
#import tensorflow as tf
import numpy as np
import pandas as pd
import sys
sys.path.append('~/PycharmProjects/feedforwardNet/')
import ffnet



#pth = "/Users/gvalmerbr/Downloads/Music/"
pth = "./"

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Read data:

# %%
data,target,frm,it,desc = ffnet.loadData(pth)
data[data != 0] = np.log10(data[data !=0])+9
data[data<0]=0

# %% [markdown]
# Set feed forward network dimensions

# %%
nn_dim = [data.shape[1],2000,1000,500,target.shape[1]]
print nn_dim
opts = {'batch_size': 100,
 'display_step': 1,
 'learning_rate': 0.001,
 'training_epochs': 100}
# Out:
# [1707, 2000, 1000, 500, 348]

# %% [markdown]
# Build neural net

# %%
ffnet.tf.reset_default_graph
saver =ffnet.tf.train.Saver()
pred, x, y, hidden = ffnet.create_ffnn(nn_dim)

# %% [markdown]
# Build cost and set optimizer

# %%
       # cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
#pred_do = tf.nn.dropout(pred,0.2)
cost = ffnet.tf.losses.mean_squared_error(y, pred)
#cost = ffnet.tf.metrics.mean_cosine_distance(y, pred,0)
optimizer = ffnet.tf.train.AdamOptimizer(learning_rate=opts['learning_rate']).minimize(cost)

# %% [markdown]
# initialize and stack up together, pred, cost and optimizer

# %%
init = ffnet.tf.global_variables_initializer()
ffnet.sess.run(init)
nnet ={'x':x,'y':y,'cost':cost,'optimizer':optimizer,'pred':pred}

# %% [markdown]
# Train!

# %%
opts['training_epochs'] = 300
tf = ffnet.nn_train(data,target,nnet,opts)
# Out:
# ('Epoch:', '0001', 'cost=', '471.204747871')
# ('Epoch:', '0002', 'cost=', '59.182244330')
# ('Epoch:', '0003', 'cost=', '2.193981382')
# ('Epoch:', '0004', 'cost=', '0.083005804')
# ('Epoch:', '0005', 'cost=', '0.075824128')
# ('Epoch:', '0006', 'cost=', '0.077019482')
# ('Epoch:', '0007', 'cost=', '0.078010080')
# ('Epoch:', '0008', 'cost=', '0.078466116')
# ('Epoch:', '0009', 'cost=', '0.078538753')
# ('Epoch:', '0010', 'cost=', '0.077835045')
# ('Epoch:', '0011', 'cost=', '0.077377291')
# ('Epoch:', '0012', 'cost=', '0.076749845')
# ('Epoch:', '0013', 'cost=', '0.076257095')
# ('Epoch:', '0014', 'cost=', '0.075670750')
# ('Epoch:', '0015', 'cost=', '0.075637727')
# ('Epoch:', '0016', 'cost=', '0.075226974')
# ('Epoch:', '0017', 'cost=', '0.075043490')
# ('Epoch:', '0018', 'cost=', '0.074831441')
# ('Epoch:', '0019', 'cost=', '0.074592041')
# ('Epoch:', '0020', 'cost=', '0.074536965')
# ('Epoch:', '0021', 'cost=', '0.074303718')
# ('Epoch:', '0022', 'cost=', '0.074288639')
# ('Epoch:', '0023', 'cost=', '0.074207916')
# ('Epoch:', '0024', 'cost=', '0.073973669')
# ('Epoch:', '0025', 'cost=', '0.074006327')
# ('Epoch:', '0026', 'cost=', '0.073836319')
# ('Epoch:', '0027', 'cost=', '0.073831795')
# ('Epoch:', '0028', 'cost=', '0.073786046')
# ('Epoch:', '0029', 'cost=', '0.073494332')
# ('Epoch:', '0030', 'cost=', '0.073444964')
# ('Epoch:', '0031', 'cost=', '0.073477780')
# ('Epoch:', '0032', 'cost=', '0.073230520')
# ('Epoch:', '0033', 'cost=', '0.073292685')
# ('Epoch:', '0034', 'cost=', '0.073225755')
# ('Epoch:', '0035', 'cost=', '0.073135290')
# ('Epoch:', '0036', 'cost=', '0.073080317')
# ('Epoch:', '0037', 'cost=', '0.073050822')
# ('Epoch:', '0038', 'cost=', '0.072945258')
# ('Epoch:', '0039', 'cost=', '0.073078038')
# ('Epoch:', '0040', 'cost=', '0.072738555')
# ('Epoch:', '0041', 'cost=', '0.072725045')
# ('Epoch:', '0042', 'cost=', '0.072623503')
# ('Epoch:', '0043', 'cost=', '0.072825318')
# ('Epoch:', '0044', 'cost=', '0.072502358')
# ('Epoch:', '0045', 'cost=', '0.072483237')
# ('Epoch:', '0046', 'cost=', '0.072345098')
# ('Epoch:', '0047', 'cost=', '0.072464984')
# ('Epoch:', '0048', 'cost=', '0.072406516')
# ('Epoch:', '0049', 'cost=', '0.072375382')
# ('Epoch:', '0050', 'cost=', '0.072138313')
# ('Epoch:', '0051', 'cost=', '0.072247621')
# ('Epoch:', '0052', 'cost=', '0.072120813')
# ('Epoch:', '0053', 'cost=', '0.072164235')
# ('Epoch:', '0054', 'cost=', '0.072074198')
# ('Epoch:', '0055', 'cost=', '0.072058379')
# ('Epoch:', '0056', 'cost=', '0.072016468')
# ('Epoch:', '0057', 'cost=', '0.071908877')
# ('Epoch:', '0058', 'cost=', '0.071819498')
# ('Epoch:', '0059', 'cost=', '0.071976634')
# ('Epoch:', '0060', 'cost=', '0.071819382')
# ('Epoch:', '0061', 'cost=', '0.071983151')
# ('Epoch:', '0062', 'cost=', '0.072108286')
# ('Epoch:', '0063', 'cost=', '0.071824503')
# ('Epoch:', '0064', 'cost=', '0.071873102')
# ('Epoch:', '0065', 'cost=', '0.071738684')
# ('Epoch:', '0066', 'cost=', '0.071735347')
# ('Epoch:', '0067', 'cost=', '0.071735907')
# ('Epoch:', '0068', 'cost=', '0.071812073')
# ('Epoch:', '0069', 'cost=', '0.071757575')
# ('Epoch:', '0070', 'cost=', '0.071727695')
# ('Epoch:', '0071', 'cost=', '0.071596973')
# ('Epoch:', '0072', 'cost=', '0.071695478')
# ('Epoch:', '0073', 'cost=', '0.071564747')
# ('Epoch:', '0074', 'cost=', '0.071544481')
# ('Epoch:', '0075', 'cost=', '0.071457586')
# ('Epoch:', '0076', 'cost=', '0.071440160')
# ('Epoch:', '0077', 'cost=', '0.071504265')
# ('Epoch:', '0078', 'cost=', '0.071400212')
# ('Epoch:', '0079', 'cost=', '0.071414713')
# ('Epoch:', '0080', 'cost=', '0.071518484')
# ('Epoch:', '0081', 'cost=', '0.071295992')
# ('Epoch:', '0082', 'cost=', '0.071159335')
# ('Epoch:', '0083', 'cost=', '0.071358772')
# ('Epoch:', '0084', 'cost=', '0.071418043')
# ('Epoch:', '0085', 'cost=', '0.071115481')
# ('Epoch:', '0086', 'cost=', '0.071318559')
# ('Epoch:', '0087', 'cost=', '0.071085505')
# ('Epoch:', '0088', 'cost=', '0.071161880')
# ('Epoch:', '0089', 'cost=', '0.071217569')
# ('Epoch:', '0090', 'cost=', '0.070972504')
# ('Epoch:', '0091', 'cost=', '0.071074762')
# ('Epoch:', '0092', 'cost=', '0.071037208')
# ('Epoch:', '0093', 'cost=', '0.071020806')
# ('Epoch:', '0094', 'cost=', '0.070980691')
# ('Epoch:', '0095', 'cost=', '0.071039514')
# ('Epoch:', '0096', 'cost=', '0.071076721')
# ('Epoch:', '0097', 'cost=', '0.070845488')
# ('Epoch:', '0098', 'cost=', '0.070934284')
# ('Epoch:', '0099', 'cost=', '0.070685217')
# ('Epoch:', '0100', 'cost=', '0.070751976')
# ('Epoch:', '0101', 'cost=', '0.070885200')
# ('Epoch:', '0102', 'cost=', '0.070769950')
# ('Epoch:', '0103', 'cost=', '0.070818798')
# ('Epoch:', '0104', 'cost=', '0.070760245')
# ('Epoch:', '0105', 'cost=', '0.070873001')
# ('Epoch:', '0106', 'cost=', '0.070783340')
# ('Epoch:', '0107', 'cost=', '0.070843211')
# ('Epoch:', '0108', 'cost=', '0.070651570')
# ('Epoch:', '0109', 'cost=', '0.070641757')
# ('Epoch:', '0110', 'cost=', '0.070631570')
# ('Epoch:', '0111', 'cost=', '0.070707517')
# ('Epoch:', '0112', 'cost=', '0.070601592')
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-46-43496ed37f6f> in <module>()
#       1 opts['training_epochs'] = 300
# ----> 2 tf = ffnet.nn_train(data,target,nnet,opts)
#
# /work/ffnet.pyc in nn_train(data, target, nnet, opts)
#      67         # Loop over all batches
#      68         for i in range(total_batch):
# ---> 69             batch_x, batch_y = getSlice(data,target,opts['batch_size'])
#      70             # Run optimization op (backprop) and cost op (to get loss value)
#      71             _, c = sess.run([optimizer, cost], feed_dict={x: batch_x,
#
# /work/ffnet.pyc in getSlice(x, y, batchsize)
#      46 def getSlice(x,y,batchsize):
#      47     idx = np.random.randint(0,y.shape[0], batchsize)
# ---> 48     return x[idx, :], y[idx, :]
#      49
#      50
#
# KeyboardInterrupt:

# %%
d = data[:,:]
p = pred.eval(feed_dict={x: d})

final_cost = cost.eval(feed_dict={x: d,y:target[:,:]})
print("Cost = ",final_cost)
print("max of pred = ",p.max())
# Out:
# ('Cost = ', 0.070680648)
# ('max of pred = ', 4.3017836)

# %%
ffnet.sess.run([hidden[1],hidden[2]],feed_dict={x: d})

# %%
import matplotlib.pyplot as plt

# %matplotlib notebook
fig=plt.figure()
h=plt.imshow(p,aspect='auto')
fig.colorbar(h,orientation='vertical')
print np.nonzero(p==p.max())
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([25986]), array([115]))

# %%
r = pd.DataFrame(np.transpose(p[10000]),index=desc)
print r.shape
r.nlargest(18,0)
# Out:
# (348, 1)
#                   0
# AROMATIC   1.455561
# WOODY      1.041347
# CITRUS     1.009964
# FLORAL     0.964007
# GREEN      0.917523
# LAVENDER   0.727512
# PINE       0.537529
# ALDEHYDIC  0.525063
# FOUGERE    0.516947
# SPICY      0.515547
# FRUITY     0.441614
# HERBAL     0.440218
# COLOGNE    0.379496
# MUSK       0.374026
# MENTHOL    0.306206
# MINT       0.300834
# LIME       0.256775
# ANISEED    0.242187

# %%
r = pd.DataFrame(np.transpose(target[10000]),index=desc)
print r.shape
r.nlargest(3,0)
# Out:
# (348, 1)
#              0
# PINE       4.0
# ALDEHYDIC  3.5
# ACACIA     0.0

# %%
s = 'OlfModel_' + '_'.join(str(d) for d in nn_dim) + '_err='+ '%.2f' % (final_cost)+'.tf'
print "saving", s
saver.save(ffnet.sess, "./saved_model/"+ s)
print 'done'
# Out:
# saving OlfModel_1707_2000_1000_500_348_err=0.07.tf
# done

# %%
# !jupyter nbconvert --to script LearnOlfModel_from_RM.ipynb
# Out:
# [NbConvertApp] Converting notebook LearnOlfModel_from_RM.ipynb to script
# [NbConvertApp] Writing 2551 bytes to LearnOlfModel_from_RM.py

# %%
v =l1.read_value()

# %%
v.shape

# %%
print v

# %%
print ffnet.getSlice(data,target,10)

# %%
e =target-p
me =sum(sum(e**2))/e.shape[0]
print me

# %%
print hidden
